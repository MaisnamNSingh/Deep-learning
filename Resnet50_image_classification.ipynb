# %% [markdown]
# # Transfer learning with ResNet50 for image classification with Keras

# %%
# %matplotlib inline
from keras.applications.resnet50 import ResNet50
from keras.models import Model
from keras import optimizers
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization
from keras.metrics import categorical_accuracy
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping
import keras
import keras.utils
#from keras.utils import to_categorical
from keras.utils.np_utils import to_categorical
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt

# %%
model = ResNet50(weights='imagenet')

# %%
img_path = "elephant.jpg"

# %%
from keras.preprocessing import image

# %%
img = image.load_img(img_path,target_size=(224,224))

# %%
x = image.img_to_array(img)

# %%
plt.imshow(x/255.)

# %%
import numpy as np

# %%
x= np.expand_dims(x,axis=0)

# %%
from keras.applications.resnet50 import preprocess_input,decode_predictions

# %%
x = preprocess_input(x)

# %%
preds = model.predict(x)

# %%
print("Predicted:",decode_predictions(preds))
# Out:
# Predicted: [[('n02504458', 'African_elephant', 0.67818028), ('n01871265', 'tusker', 0.31328651), ('n02504013', 'Indian_elephant', 0.0085115926), ('n02408429', 'water_buffalo', 4.1021644e-06), ('n02480855', 'gorilla', 2.9258192e-06)]]

# %%
# Although predicts as elephant but still it comes up with 'water_buffalo' and 'gorilla'
